# %%
import pandas as pd
import matplotlib as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/mbrito/Desktop/Data Science/Curso LabHacker/CURSOS PROUNI 2018.csv')

# %%
df.head()
# Out:
#   uf_busca     cidade_busca  \
# 0       AC       Acrelandia
# 1       AC  Cruzeiro do Sul
# 2       AC  Cruzeiro do Sul
# 3       AC  Cruzeiro do Sul
# 4       AC       Rio Branco
#
#                                    universidade_nome  \
# 0                       Universidade Paulista - UNIP
# 1  Centro Universitário Internacional - Uninter -...
# 2               Faculdade Educacional da Lapa - FAEL
# 3                       Universidade Paulista - UNIP
# 4  Centro Universitário Internacional - Uninter -...
#
#                                 campus_nome           nome         grau  \
# 0                       ACRELANDIA - Centro  Administração  Bacharelado
# 1              PAP CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 2  AC - CRUZEIRO DO SUL - POLO EAD - CENTRO  Administração  Bacharelado
# 3                  CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 4                   PAP RIO BRANCO - Bosque  Administração  Bacharelado
#
# ...

# %%
df.columns.str.upper()
# Out:
# Index(['UF_BUSCA', 'CIDADE_BUSCA', 'UNIVERSIDADE_NOME', 'CAMPUS_NOME', 'NOME',
#        'GRAU', 'TURNO', 'MENSALIDADE', 'BOLSA_INTEGRAL_COTAS',
#        'BOLSA_INTEGRAL_AMPLA', 'BOLSA_PARCIAL_COTAS', 'BOLSA_PARCIAL_AMPLA',
#        'NOTA_INTEGRAL_AMPLA', 'NOTA_INTEGRAL_COTAS', 'NOTA_PARCIAL_AMPLA',
#        'NOTA_PARCIAL_COTAS'],
#       dtype='object')

# %%
df.head()
# Out:
#   uf_busca     cidade_busca  \
# 0       AC       Acrelandia
# 1       AC  Cruzeiro do Sul
# 2       AC  Cruzeiro do Sul
# 3       AC  Cruzeiro do Sul
# 4       AC       Rio Branco
#
#                                    universidade_nome  \
# 0                       Universidade Paulista - UNIP
# 1  Centro Universitário Internacional - Uninter -...
# 2               Faculdade Educacional da Lapa - FAEL
# 3                       Universidade Paulista - UNIP
# 4  Centro Universitário Internacional - Uninter -...
#
#                                 campus_nome           nome         grau  \
# 0                       ACRELANDIA - Centro  Administração  Bacharelado
# 1              PAP CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 2  AC - CRUZEIRO DO SUL - POLO EAD - CENTRO  Administração  Bacharelado
# 3                  CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 4                   PAP RIO BRANCO - Bosque  Administração  Bacharelado
#
# ...

# %%
df.columns = ['UF_BUSCA', 'CIDADE_BUSCA', 'UNIVERSIDADE_NOME', 'CAMPUS_NOME', 'NOME', 'GRAU', 'TURNO', 'MENSALIDADE', 'BOLSA_INTEGRAL_COTAS', 'BOLSA_INTEGRAL_AMPLA', 'BOLSA_PARCIAL_COTAS', 'BOLSA_PARCIAL_AMPLA', 'NOTA_INTEGRAL_AMPLA', 'NOTA_INTEGRAL_COTAS', 'NOTA_PARCIAL_AMPLA', 'NOTA_PARCIAL_COTAS']

# %%
df.head()
# Out:
#   UF_BUSCA     CIDADE_BUSCA  \
# 0       AC       Acrelandia
# 1       AC  Cruzeiro do Sul
# 2       AC  Cruzeiro do Sul
# 3       AC  Cruzeiro do Sul
# 4       AC       Rio Branco
#
#                                    UNIVERSIDADE_NOME  \
# 0                       Universidade Paulista - UNIP
# 1  Centro Universitário Internacional - Uninter -...
# 2               Faculdade Educacional da Lapa - FAEL
# 3                       Universidade Paulista - UNIP
# 4  Centro Universitário Internacional - Uninter -...
#
#                                 CAMPUS_NOME           NOME         GRAU  \
# 0                       ACRELANDIA - Centro  Administração  Bacharelado
# 1              PAP CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 2  AC - CRUZEIRO DO SUL - POLO EAD - CENTRO  Administração  Bacharelado
# 3                  CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 4                   PAP RIO BRANCO - Bosque  Administração  Bacharelado
#
# ...

# %%
df.count()
# Out:
# UF_BUSCA                41447
# CIDADE_BUSCA            41447
# UNIVERSIDADE_NOME       41447
# CAMPUS_NOME             41447
# NOME                    41447
# GRAU                    41447
# TURNO                   41447
# MENSALIDADE             41447
# BOLSA_INTEGRAL_COTAS    32520
# BOLSA_INTEGRAL_AMPLA    25404
# BOLSA_PARCIAL_COTAS      8828
# BOLSA_PARCIAL_AMPLA     13041
# NOTA_INTEGRAL_AMPLA     32520
# NOTA_INTEGRAL_COTAS     16802
# NOTA_PARCIAL_AMPLA      16350
# NOTA_PARCIAL_COTAS       5519
# dtype: int64

# %%
df['GRAU'].value_counts().plot.barh()

# %%
#FORMATO DO SHAPE (LINHAS E COLUNAS)

df.shape
# Out:
# (41447, 16)

# %%
df.dtypes
# Out:
# UF_BUSCA                 object
# CIDADE_BUSCA             object
# UNIVERSIDADE_NOME        object
# CAMPUS_NOME              object
# NOME                     object
# GRAU                     object
# TURNO                    object
# MENSALIDADE             float64
# BOLSA_INTEGRAL_COTAS    float64
# BOLSA_INTEGRAL_AMPLA    float64
# BOLSA_PARCIAL_COTAS     float64
# BOLSA_PARCIAL_AMPLA     float64
# NOTA_INTEGRAL_AMPLA     float64
# NOTA_INTEGRAL_COTAS     float64
# NOTA_PARCIAL_AMPLA      float64
# NOTA_PARCIAL_COTAS      float64
# dtype: object

# %%
df.describe()
# Out:
#         MENSALIDADE  BOLSA_INTEGRAL_COTAS  BOLSA_INTEGRAL_AMPLA  \
# count  41447.000000          32520.000000          25404.000000
# mean     622.636966              1.535394              2.513541
# std      606.442296              2.191578              3.019549
# min      139.000000              0.000000              1.000000
# 25%      278.000000              0.000000              1.000000
# 50%      393.350000              1.000000              1.000000
# 75%      825.000000              2.000000              3.000000
# max     9999.990000             58.000000             67.000000
#
#        BOLSA_PARCIAL_COTAS  BOLSA_PARCIAL_AMPLA  NOTA_INTEGRAL_AMPLA  \
# count          8828.000000         13041.000000         32520.000000
# mean              1.873018             8.632544           575.982999
# std               2.336403            18.372991            57.827594
# min               1.000000             1.000000           450.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 16 columns):
# UF_BUSCA                41447 non-null object
# CIDADE_BUSCA            41447 non-null object
# UNIVERSIDADE_NOME       41447 non-null object
# CAMPUS_NOME             41447 non-null object
# NOME                    41447 non-null object
# GRAU                    41447 non-null object
# TURNO                   41447 non-null object
# MENSALIDADE             41447 non-null float64
# BOLSA_INTEGRAL_COTAS    32520 non-null float64
# BOLSA_INTEGRAL_AMPLA    25404 non-null float64
# BOLSA_PARCIAL_COTAS     8828 non-null float64
# BOLSA_PARCIAL_AMPLA     13041 non-null float64
# NOTA_INTEGRAL_AMPLA     32520 non-null float64
# NOTA_INTEGRAL_COTAS     16802 non-null float64
# NOTA_PARCIAL_AMPLA      16350 non-null float64
# NOTA_PARCIAL_COTAS      5519 non-null float64
# dtypes: float64(9), object(7)
# memory usage: 5.1+ MB

# %%
df['UNIVERSIDADE_NOME'].value_counts(ascending=True).plot.bar()

# %%
df_SP = df[df['UF_BUSCA'] == 'SP']

# %%
df_SP.sample()
# Out:
#       UF_BUSCA CIDADE_BUSCA                  UNIVERSIDADE_NOME  \
# 17201       SP     Sorocaba  Universidade Anhanguera - UNIDERP
#
#                          CAMPUS_NOME                 NOME         GRAU  \
# 17201  SOROCABA/SP (23043) - Itangua  Engenharia Mecânica  Bacharelado
#
#                    TURNO  MENSALIDADE  BOLSA_INTEGRAL_COTAS  \
# 17201  Curso a Distância        589.0                   0.0
#
#        BOLSA_INTEGRAL_AMPLA  BOLSA_PARCIAL_COTAS  BOLSA_PARCIAL_AMPLA  \
# 17201                   1.0                  NaN                  NaN
#
#        NOTA_INTEGRAL_AMPLA  NOTA_INTEGRAL_COTAS  NOTA_PARCIAL_AMPLA  \
# 17201               572.18                  NaN                 NaN
#
#        NOTA_PARCIAL_COTAS
# 17201                 NaN

# %%
df_SP['NOME'].value_counts(ascending=True).plot.bar()

# %%
df_SP_SP = df_SP[df_SP['CIDADE_BUSCA'] == 'Sao Paulo']

# %%
df_SP_SP.sample(50)
# Out:
#       UF_BUSCA CIDADE_BUSCA  \
# 38818       SP    Sao Paulo
# 35619       SP    Sao Paulo
# 6421        SP    Sao Paulo
# 5076        SP    Sao Paulo
# 8697        SP    Sao Paulo
# 32915       SP    Sao Paulo
# 36756       SP    Sao Paulo
# 15245       SP    Sao Paulo
# 14825       SP    Sao Paulo
# 22112       SP    Sao Paulo
# 8708        SP    Sao Paulo
# 38368       SP    Sao Paulo
# 5592        SP    Sao Paulo
# 28466       SP    Sao Paulo
# 8435        SP    Sao Paulo
# 13620       SP    Sao Paulo
# 5808        SP    Sao Paulo
# 20809       SP    Sao Paulo
# 5809        SP    Sao Paulo
# 17193       SP    Sao Paulo
# 27883       SP    Sao Paulo
# 25602       SP    Sao Paulo
# 32920       SP    Sao Paulo
# 8363        SP    Sao Paulo
# 35589       SP    Sao Paulo
# 40359       SP    Sao Paulo
# 30148       SP    Sao Paulo
# 5795        SP    Sao Paulo
# 30179       SP    Sao Paulo
# 35616       SP    Sao Paulo
# 36755       SP    Sao Paulo
# 27807       SP    Sao Paulo
# ...

# %%
df_SP_SP['NOME'].value_counts(ascending=True).plot.bar()

# %%
df_SP_SP_UNIVERSIDADE = df_SP[df_SP['UNIVERSIDADE_NOME'] == 'Universidade Presbiteriana Mackenzie - MACKENZIE']

# %%
df_SP_SP_UNIVERSIDADE['NOME'].value_counts(ascending=True).plot.bar()

# %%
df_SP_SP.MENSALIDADE.unique()
# Out:
# array([1649.  , 1249.  ,  498.  ,  428.  , 1348.  ,  749.  ,  336.25,
#         619.  ,  417.14,  627.14,  684.29,  519.  ,  298.  ,  560.56,
#        1094.  ,  515.  ,  350.  ,  250.  ,  978.68,  838.87,  692.1 ,
#         850.  ,  680.  , 1395.  , 1025.  ,  325.  ,  790.  ,  388.  ,
#         894.24,  650.1 ,  750.  ,  418.  ,  538.2 ,  175.  , 2522.  ,
#        2415.3 ,  289.  , 1159.  , 1065.  ,  439.11,  290.42,  676.46,
#         598.45,  698.84,  598.47,  289.97,  598.83,  529.82,  798.87,
#         857.28,  700.8 , 1249.98,  638.  ,  513.  ,  257.  ,  436.  ,
#         574.  ,  461.  ,  717.22,  633.2 ,  539.04,  700.31,  580.17,
#         606.14,  497.9 ,  647.28,  659.39,  532.13,  636.45,  599.12,
#         717.63,  671.09,  605.06,  495.58,  679.75,  329.  , 2124.  ,
#        1410.  ,  579.  ,  448.  ,  549.  ,  433.  ,  399.  , 1420.  ,
#         648.  ,  468.  ,  538.  ,  490.  ,  360.  ,  388.57,  274.  ,
# ...

# %%
df_SP_SP.UNIVERSIDADE_NOME.unique()
# Out:
# array(['Centro Universitário Álvares Penteado - Fecap - FECAP',
#        'Centro Universitário Anhanguera de São Paulo',
#        'Centro Universitário Campos de Andrade - Uniandrade - UNIANDRADE',
#        'Centro Universitário da Fundação Educacional Inaciana Pe Sabóia de Medeiros - Fei - FEI',
#        'Centro Universitário das Faculdades Metropolitanas Unidas - Fmu - FMU',
#        'Centro Universitário Estácio de Ribeirão Preto - Estácio Ribeirão Pre - ESTÁCIO RIBEIRÃO PRE',
#        'Centro Universitário Estácio de São Paulo - Estácio São Paulo - ESTÁCIO SÃO PAULO',
#        'Centro Universitário Ibta',
#        'Centro Universitário Internacional - Uninter - UNINTER',
#        'Centro Universitário São Camilo - SAO CAMILO',
#        'Centro Universitário Senac - SENACSP',
#        'Faculdade Autônoma de Direito - FADISP',
#        'Faculdade Campos Elíseos - FCE',
#        'Faculdade Carlos Drummond de Andrade - FCDA',
# ...

# %%
#DEPOIS DO IGUAL INSERIR O NOME DO CURSO PARA SABER O VALOR DA MENSALIDADE

df_SP_SP_UNIVERSIDADE_CURSO = df_SP_SP_UNIVERSIDADE[df_SP_SP_UNIVERSIDADE['NOME'] == 'Marketing']

# %%
df_SP_SP_UNIVERSIDADE_CURSO.head()
# Out:
#       UF_BUSCA           CIDADE_BUSCA  \
# 30758       SP                Barueri
# 30783       SP               Campinas
# 30893       SP  Sao Jose do Rio Preto
# 30981       SP              Sao Paulo
# 30982       SP              Sao Paulo
#
#                                       UNIVERSIDADE_NOME  \
# 30758  Universidade Presbiteriana Mackenzie - MACKENZIE
# 30783  Universidade Presbiteriana Mackenzie - MACKENZIE
# 30893  Universidade Presbiteriana Mackenzie - MACKENZIE
# 30981  Universidade Presbiteriana Mackenzie - MACKENZIE
# 30982  Universidade Presbiteriana Mackenzie - MACKENZIE
#
#                                              CAMPUS_NOME       NOME  \
# 30758                                  TAMBORÉ - Tamboré  Marketing
# 30783             CAMPUS  DE CAMPINAS - Jardim Guanabara  Marketing
# 30893  POLO DE APOIO PRESENCIAL - SÃO JOSÉ DO RIO PRE...  Marketing
# 30981      CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação  Marketing
# ...

# %%
df_SP_SP_UNIVERSIDADE.NOME.unique()
# Out:
# array(['Administração', 'Análise e Desenvolvimento de Sistemas',
#        'Arquitetura e Urbanismo', 'Ciência da Computação',
#        'Ciências Biológicas', 'Ciências Contábeis', 'Ciências Econômicas',
#        'Comunicação Social - Publicidade e Propaganda', 'Direito',
#        'Engenharia Civil', 'Engenharia de Materiais',
#        'Engenharia de Produção', 'Engenharia Elétrica',
#        'Engenharia Mecânica', 'Farmácia', 'Filosofia', 'Fisioterapia',
#        'Gastronomia', 'Gestão Comercial', 'Gestão de Recursos Humanos',
#        'Jornalismo', 'Letras Português e Inglês', 'Marketing',
#        'Matemática', 'Nutrição', 'Pedagogia', 'Psicologia', 'Química',
#        'Sistemas de Informação', 'Teologia'], dtype=object)

# %%
df_SP_SP_UNIVERSIDADE['CAMPUS_NOME'].value_counts()
# Out:
# CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação                42
# CAMPUS  DE CAMPINAS - Jardim Guanabara                        8
# TAMBORÉ - Tamboré                                             3
# POLO DE APOIO PRESENCIAL - SÃO PAULO BRÁS - Belenzinho        3
# POLO DE APOIO PRESENCIAL - SÃO JOSÉ DO RIO PRETO - Centro     1
# Name: CAMPUS_NOME, dtype: int64

# %%
df_SP_SP_UNIVERSIDADE[df_SP_SP_UNIVERSIDADE['MENSALIDADE'] == df_SP_SP_UNIVERSIDADE['MENSALIDADE'].max()]
# Out:
#      UF_BUSCA CIDADE_BUSCA                                 UNIVERSIDADE_NOME  \
# 4578       SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
# 4579       SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
# 4580       SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
#
#                                         CAMPUS_NOME                     NOME  \
# 4578  CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação  Arquitetura e Urbanismo
# 4579  CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação  Arquitetura e Urbanismo
# 4580  CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação  Arquitetura e Urbanismo
#
#              GRAU       TURNO  MENSALIDADE  BOLSA_INTEGRAL_COTAS  \
# 4578  Bacharelado    Matutino       2957.0                   3.0
# 4579  Bacharelado  Vespertino       2957.0                   1.0
# 4580  Bacharelado     Noturno       2957.0                   6.0
#
#       BOLSA_INTEGRAL_AMPLA  BOLSA_PARCIAL_COTAS  BOLSA_PARCIAL_AMPLA  \
# ...

# %%
df_SP_SP_UNIVERSIDADE[df_SP_SP_UNIVERSIDADE['MENSALIDADE'] == df_SP_SP_UNIVERSIDADE['MENSALIDADE'].min()]
# Out:
#       UF_BUSCA           CIDADE_BUSCA  \
# 21485       SP                Barueri
# 21504       SP               Campinas
# 21684       SP              Sao Paulo
# 24273       SP              Sao Paulo
# 24274       SP              Sao Paulo
# 30758       SP                Barueri
# 30783       SP               Campinas
# 30893       SP  Sao Jose do Rio Preto
# 30981       SP              Sao Paulo
# 30982       SP              Sao Paulo
#
#                                       UNIVERSIDADE_NOME  \
# 21485  Universidade Presbiteriana Mackenzie - MACKENZIE
# 21504  Universidade Presbiteriana Mackenzie - MACKENZIE
# 21684  Universidade Presbiteriana Mackenzie - MACKENZIE
# 24273  Universidade Presbiteriana Mackenzie - MACKENZIE
# 24274  Universidade Presbiteriana Mackenzie - MACKENZIE
# 30758  Universidade Presbiteriana Mackenzie - MACKENZIE
# 30783  Universidade Presbiteriana Mackenzie - MACKENZIE
# 30893  Universidade Presbiteriana Mackenzie - MACKENZIE
# ...

# %%
df_SP_SP_UNIVERSIDADE.describe()
# Out:
#        MENSALIDADE  BOLSA_INTEGRAL_COTAS  BOLSA_INTEGRAL_AMPLA  \
# count    57.000000             57.000000             57.000000
# mean   1664.438596              2.982456              5.964912
# std     832.981157              3.102368              5.725772
# min     300.000000              0.000000              1.000000
# 25%     979.000000              1.000000              2.000000
# 50%    2018.000000              2.000000              3.000000
# 75%    2153.000000              4.000000              7.000000
# max    2957.000000             12.000000             23.000000
#
#        BOLSA_PARCIAL_COTAS  BOLSA_PARCIAL_AMPLA  NOTA_INTEGRAL_AMPLA  \
# count                  0.0                  0.0            57.000000
# mean                   NaN                  NaN           661.756842
# std                    NaN                  NaN            33.701923
# min                    NaN                  NaN           555.120000
# ...

# %%
df_SP_SP_UNIVERSIDADE['MENSALIDADE'].nlargest()
# Out:
# 4578     2957.0
# 4579     2957.0
# 4580     2957.0
# 16067    2748.0
# 16068    2748.0
# Name: MENSALIDADE, dtype: float64

# %%
df.groupby('UF_BUSCA')['MENSALIDADE'].max()
# Out:
# UF_BUSCA
# AC    9674.34
# AL    7290.00
# AM    2127.05
# AP    3607.62
# BA    9048.00
# CE    9836.40
# DF    6757.92
# ES    6022.28
# GO    6484.47
# MA    8281.38
# MG    9350.00
# MS    9999.99
# MT    9208.00
# PA    8508.54
# PB    8350.00
# PE    7250.00
# PI    8402.00
# PR    8466.72
# RJ    9023.07
# RN    6505.09
# RO    6909.97
# RR    1463.05
# RS    8329.95
# SC    6922.15
# SE    6490.00
# SP    9715.61
# TO    7800.00
# Name: MENSALIDADE, dtype: float64

# %%
df.groupby('UF_BUSCA')['MENSALIDADE'].min()
# Out:
# UF_BUSCA
# AC    149.0
# AL    149.0
# AM    149.0
# AP    149.0
# BA    149.0
# CE    169.0
# DF    139.0
# ES    139.0
# GO    149.0
# MA    149.0
# MG    149.0
# MS    149.0
# MT    149.0
# PA    139.0
# PB    149.0
# PE    149.0
# PI    149.0
# PR    149.0
# RJ    149.0
# RN    149.0
# RO    149.0
# RR    169.0
# RS    149.0
# SC    149.0
# SE    169.0
# SP    144.0
# TO    149.0
# Name: MENSALIDADE, dtype: float64

# %%
df_SP_SP.loc[df_SP_SP.groupby('UF_BUSCA')['MENSALIDADE'].idxmax()]
# Out:
#       UF_BUSCA CIDADE_BUSCA                          UNIVERSIDADE_NOME  \
# 32058       SP    Sao Paulo  Universidade Cidade de São Paulo - UNICID
#
#                                              CAMPUS_NOME      NOME  \
# 32058  UNIVERSIDADE CIDADE DE SÃO PAULO - UNICID - SE...  Medicina
#
#               GRAU     TURNO  MENSALIDADE  BOLSA_INTEGRAL_COTAS  \
# 32058  Bacharelado  Integral      9715.61                   2.0
#
#        BOLSA_INTEGRAL_AMPLA  BOLSA_PARCIAL_COTAS  BOLSA_PARCIAL_AMPLA  \
# 32058                   5.0                  6.0                 10.0
#
#        NOTA_INTEGRAL_AMPLA  NOTA_INTEGRAL_COTAS  NOTA_PARCIAL_AMPLA  \
# 32058               739.62               738.08              738.96
#
#        NOTA_PARCIAL_COTAS
# 32058              718.64

# %%
df.loc[df.groupby('UF_BUSCA')['MENSALIDADE'].idxmax()]
# Out:
#       UF_BUSCA      CIDADE_BUSCA  \
# 31940       AC        Rio Branco
# 31941       AL            Maceio
# 32962       AM            Manaus
# 32966       AP            Macapa
# 31945       BA  Lauro de Freitas
# 12916       CE           Crateus
# 31950       DF          Brasilia
# 31952       ES          Colatina
# 31957       GO           Goiania
# 31959       MA        Imperatriz
# 31983       MG  Sao Joao Del Rei
# 31987       MS      Campo Grande
# 31988       MT            Cuiaba
# 31990       PA             Belem
# 31995       PB       Joao Pessoa
# 31997       PE            Olinda
# 32001       PI          Parnaiba
# 11916       PR          Curitiba
# 32012       RJ         Itaperuna
# 32017       RN             Natal
# 32019       RO       Porto Velho
# 33143       RR         Boa VIsta
# 32022       RS     Caxias do Sul
# 32036       SC        Rio do Sul
# 32038       SE           Aracaju
# 32058       SP         Sao Paulo
# 32062       TO            Palmas
#
# ...

# %%
df.head()
# Out:
#   UF_BUSCA     CIDADE_BUSCA  \
# 0       AC       Acrelandia
# 1       AC  Cruzeiro do Sul
# 2       AC  Cruzeiro do Sul
# 3       AC  Cruzeiro do Sul
# 4       AC       Rio Branco
#
#                                    UNIVERSIDADE_NOME  \
# 0                       Universidade Paulista - UNIP
# 1  Centro Universitário Internacional - Uninter -...
# 2               Faculdade Educacional da Lapa - FAEL
# 3                       Universidade Paulista - UNIP
# 4  Centro Universitário Internacional - Uninter -...
#
#                                 CAMPUS_NOME           NOME         GRAU  \
# 0                       ACRELANDIA - Centro  Administração  Bacharelado
# 1              PAP CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 2  AC - CRUZEIRO DO SUL - POLO EAD - CENTRO  Administração  Bacharelado
# 3                  CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 4                   PAP RIO BRANCO - Bosque  Administração  Bacharelado
#
# ...

# %%
#TOP 5 MENSALIDADES

df_SP_SP_UNIVERSIDADE.nlargest(5, 'MENSALIDADE')
# Out:
#       UF_BUSCA CIDADE_BUSCA                                 UNIVERSIDADE_NOME  \
# 4578        SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
# 4579        SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
# 4580        SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
# 16067       SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
# 16068       SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
#
#                                          CAMPUS_NOME                     NOME  \
# 4578   CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação  Arquitetura e Urbanismo
# 4579   CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação  Arquitetura e Urbanismo
# 4580   CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação  Arquitetura e Urbanismo
# 16067  CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação   Engenharia de Produção
# 16068  CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação   Engenharia de Produção
#
# ...

# %%
#TOP DOWN 5 MENSALIDADES

df_SP_SP_UNIVERSIDADE.nsmallest(5, 'MENSALIDADE')
# Out:
#       UF_BUSCA CIDADE_BUSCA                                 UNIVERSIDADE_NOME  \
# 21485       SP      Barueri  Universidade Presbiteriana Mackenzie - MACKENZIE
# 21504       SP     Campinas  Universidade Presbiteriana Mackenzie - MACKENZIE
# 21684       SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
# 24273       SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
# 24274       SP    Sao Paulo  Universidade Presbiteriana Mackenzie - MACKENZIE
#
#                                              CAMPUS_NOME  \
# 21485                                  TAMBORÉ - Tamboré
# 21504             CAMPUS  DE CAMPINAS - Jardim Guanabara
# 21684      CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação
# 24273      CAMPUS  - SÃO PAULO - CONSOLAÇÃO - Consolação
# 24274  POLO DE APOIO PRESENCIAL - SÃO PAULO BRÁS - Be...
#
#                              NOME         GRAU              TURNO  \
# 21485            Gestão Comercial  Tecnológico  Curso a Distância
# ...

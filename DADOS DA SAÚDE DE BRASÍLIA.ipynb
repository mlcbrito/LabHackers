# %%
import pandas as pd

# %%
#SEP -> INDICA QUAL SEPARADOR ESTÁ SENDO UTILIZADO NO ARQUIVO
#ENCODING -> É O CODIGO DA COVERSÃO DO ARQUIVO -> DE EXCEL PARA CSV USAR CP1252

df = pd.read_csv('C:/Users/mbrito/Desktop/Data Science/Curso LabHacker/sia112018.csv', sep=';', encoding='cp1252')

# %%
df.head()
# Out:
#    ano_mes  cod_estabelecimento_cnes              estabelecimento_cnes  \
# 0   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 1   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 2   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 3   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 4   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
#
#         complexidade  cod_grupo              grupo  cod_subgrupo  \
# 0  Alta complexidade          6  06 - Medicamentos           604
# 1  Alta complexidade          6  06 - Medicamentos           604
# 2  Alta complexidade          6  06 - Medicamentos           604
# 3  Alta complexidade          6  06 - Medicamentos           604
# 4  Alta complexidade          6  06 - Medicamentos           604
#
#                                             subgrupo  cod_procedimento  \
# 0  Sub Grupo: 04 - Componente Especializado da As...         604320132
# ...

# %%
df.count()
# Out:
# ano_mes                     180282
# cod_estabelecimento_cnes    180282
# estabelecimento_cnes        180282
# complexidade                180282
# cod_grupo                   180282
# grupo                       180282
# cod_subgrupo                180282
# subgrupo                    180282
# cod_procedimento            180282
# procedimento                180171
# quantidade                  180282
# cod_carater_atendimento     180282
# carater_atendimento         180282
# cod_form_organização        180282
# dtype: int64

# %%
df['procedimento'].value_counts().tail()
# Out:
# Quimioterapia da Doença de Hodgkin - 2ª Linha                                                           1
# Manutenção Periodica de Prótese Buco-maxilo-facial                                                      1
# Regulacão Medica de Urgência da Central Samu 192 c/ Acionamento de Multiplos Meios                      1
# Samu 192: Envio de Unidade de Suporte Avançado de Vida Terrestre (usa) e/ou Aquatico (equipe de Emba    1
# Exame Neuropsicomotor Evolutivo                                                                         1
# Name: procedimento, dtype: int64

# %%
# %matplotlib inline

# %%
df['grupo'].value_counts().plot.bar()

# %%
#INFORMANDO QUAIS AS COLUNAS DEVE TRAZER

df = pd.read_csv('C:/Users/mbrito/Desktop/Data Science/Curso LabHacker/sia112018.csv', sep=';', encoding='cp1252', usecols=[2, 3, 5, 7, 9, 10, 12])

# %%
df.head()
# Out:
#                estabelecimento_cnes       complexidade              grupo  \
# 0  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade  06 - Medicamentos
# 1  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade  06 - Medicamentos
# 2  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade  06 - Medicamentos
# 3  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade  06 - Medicamentos
# 4  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade  06 - Medicamentos
#
#                                             subgrupo  \
# 0  Sub Grupo: 04 - Componente Especializado da As...
# 1  Sub Grupo: 04 - Componente Especializado da As...
# 2  Sub Grupo: 04 - Componente Especializado da As...
# 3  Sub Grupo: 04 - Componente Especializado da As...
# 4  Sub Grupo: 04 - Componente Especializado da As...
#
#                            procedimento  quantidade carater_atendimento
# 0      Fingolimode 0,5 Mg (por Cápsula)          28             Eletivo
# ...

# %%
# %matplotlib inline

# %%
df['carater_atendimento'].value_counts().plot.bar()

# %%
#RENOMEAR AS COLUNAS

df.columns = ['FARMÁCIA', 'COMPLEXIDADE', 'GRUPO', 'SUBGRUPO', 'MEDICAÇÃO', 'QUANTIDADE', 'CARÁTER']

# %%
df.head()
# Out:
#                            FARMÁCIA       COMPLEXIDADE              GRUPO  \
# 0  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 1  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 2  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 3  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 4  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
#
#                                             SUBGRUPO  \
# 0  Sub Grupo: 04 - Componente Especializado da As...
# 1  Sub Grupo: 04 - Componente Especializado da As...
# 2  Sub Grupo: 04 - Componente Especializado da As...
# 3  Sub Grupo: 04 - Componente Especializado da As...
# 4  Sub Grupo: 04 - Componente Especializado da As...
#
#                               MEDICAÇÃO  QUANTIDADE  CARÁTER
# 0      Fingolimode 0,5 Mg (por Cápsula)          28  ELETIVO
# 1  Ciprofibrato 100 Mg (por Comprimido)          30  ELETIVO
# ...

# %%
#CONTAR VALORES DE DETERMINADA COLUNA

df.CARÁTER.value_counts()
# Out:
# ELETIVO                                                            137468
# BPA-C                                                               38646
# URGÊNCIA                                                             4158
# ACIDENTE NO TRAJETO PARA O TRABALHO                                     5
# ACIDENTE NO LOCAL TRABALHO OU A SERVIÇO DA EMPRESA                      3
# OUTROS TIPO DE ACIDENTE DE TRÂNSITO                                     1
# OUTROS TIPOS LESÕES/ENVENENAMENTOS POR AGENTES QUÍMICOS/FÍSICOS         1
# Name: CARÁTER, dtype: int64

# %%
#EXIBE OS VALORES ÚNICOS DA COLUNA

df.CARÁTER.unique()
# Out:
# array(['ELETIVO', 'URGÊNCIA', 'BPA-C',
#        'ACIDENTE NO LOCAL TRABALHO OU A SERVIÇO DA EMPRESA',
#        'ACIDENTE NO TRAJETO PARA O TRABALHO',
#        'OUTROS TIPO DE ACIDENTE DE TRÂNSITO',
#        'OUTROS TIPOS LESÕES/ENVENENAMENTOS POR AGENTES QUÍMICOS/FÍSICOS'],
#       dtype=object)

# %%
df.COMPLEXIDADE = df.COMPLEXIDADE.str.upper()

# %%
df.CARÁTER = df.CARÁTER.str.upper()

# %%
df.head()
# Out:
#                            FARMÁCIA       COMPLEXIDADE              GRUPO  \
# 0  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 1  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 2  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 3  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 4  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
#
#                                             SUBGRUPO  \
# 0  Sub Grupo: 04 - Componente Especializado da As...
# 1  Sub Grupo: 04 - Componente Especializado da As...
# 2  Sub Grupo: 04 - Componente Especializado da As...
# 3  Sub Grupo: 04 - Componente Especializado da As...
# 4  Sub Grupo: 04 - Componente Especializado da As...
#
#                               MEDICAÇÃO  QUANTIDADE  CARÁTER
# 0      Fingolimode 0,5 Mg (por Cápsula)          28  ELETIVO
# 1  Ciprofibrato 100 Mg (por Comprimido)          30  ELETIVO
# ...

# %%
df['SUBGRUPO'].value_counts()
# Out:
# Sub Grupo: 04 - Componente Especializado da Assitencia Farmaceutica                                  38398
# Sub Grupo: 01 - Consultas / Atendimentos / Acompanhamentos                                           38249
# Sub Grupo: 02 - Diagnóstico em laboratório clínico                                                   27327
# Sub Grupo: 03 - Diagnóstico por anatomia patológica e citopatologia                                  19364
# Sub Grupo: 05 - Diagnóstico por ultra-sonografia                                                      8315
# Sub Grupo: 06 - Diagnóstico por tomografia                                                            8018
# Sub Grupo: 02 - Fisioterapia                                                                          7207
# Sub Grupo: 11 - Métodos diagnósticos em especialidades                                                4732
# Sub Grupo: 04 - Tratamento em oncologia                                                               3766
# ...

# %%
df['COMPLEXIDADE'].value_counts().plot.bar()

# %%
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
df['SUBGRUPO'].value_counts().plot.bar()

# %%
df_FARM_ASA_SUL = df[df['FARMÁCIA'] == 'FARMACIA DE ALTO CUSTO - ASA SUL']

# %%
df_FARM_ASA_SUL.head()
# Out:
#                            FARMÁCIA       COMPLEXIDADE              GRUPO  \
# 0  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 1  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 2  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 3  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
# 4  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
#
#                                             SUBGRUPO  \
# 0  Sub Grupo: 04 - Componente Especializado da As...
# 1  Sub Grupo: 04 - Componente Especializado da As...
# 2  Sub Grupo: 04 - Componente Especializado da As...
# 3  Sub Grupo: 04 - Componente Especializado da As...
# 4  Sub Grupo: 04 - Componente Especializado da As...
#
#                               MEDICAÇÃO  QUANTIDADE  CARÁTER
# 0      Fingolimode 0,5 Mg (por Cápsula)          28  ELETIVO
# 1  Ciprofibrato 100 Mg (por Comprimido)          30  ELETIVO
# ...

# %%
#SELECIONA VALORES ALEATÓRIOS

df_FARM_ASA_SUL.sample()
# Out:
#                               FARMÁCIA       COMPLEXIDADE              GRUPO  \
# 2190  FARMACIA DE ALTO CUSTO - ASA SUL  ALTA COMPLEXIDADE  06 - Medicamentos
#
#                                                SUBGRUPO  \
# 2190  Sub Grupo: 04 - Componente Especializado da As...
#
#                                               MEDICAÇÃO  QUANTIDADE  CARÁTER
# 2190  Glatiramer 20 Mg Injetavel (por Seringa Preenc...          30  ELETIVO

# %%
df_FARM_ASA_SUL['COMPLEXIDADE'].unique()
# Out:
# array(['ALTA COMPLEXIDADE'], dtype=object)

# %%
df['SUBGRUPO'].value_counts(ascending=True).plot.barh(title = 'SUBGRUPOS')

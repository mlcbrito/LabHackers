# %%
import pandas as pd
import matplotlib as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_table('C:/Users/mbrito/Desktop/VISACAUSAS.txt', sep=';', encoding='cp1252')

# %%
df.sample(30)
# Out:
#                PromoCode  DocumentID     CardID CouponMonthYear  CouponID  \
# 18602422  VISACAUSAS2019     3340490  100315965         07/2019  84563136
# 25675891  VISACAUSAS2019     3725251   18574850         05/2019  71016801
# 31580636  VISACAUSAS2019     6541993  103643206         05/2019  67970957
# 2945839   VISACAUSAS2019     2245391  100424201         12/2018  41604010
# 34626941  VISACAUSAS2019     6718601  131986811         04/2019  62507334
# 11920567  VISACAUSAS2019     3157594  101059768         07/2019  80722861
# 6231150   VISACAUSAS2019     2436044  135142402         04/2019  64671177
# 7357505   VISACAUSAS2019     2857442  110700740         01/2019  47724578
# 6104922   VISACAUSAS2019     2424264  102837032         12/2018  40309476
# 29244198  VISACAUSAS2019     5509019  117875782         07/2019  81850894
# 18965563  VISACAUSAS2019     3438604  100376634         01/2019  44775237
# 28004867  VISACAUSAS2019     3648120  103631247         03/2019  54572289
# ...

# %%
df.tail(20)
# Out:
#                PromoCode  DocumentID     CardID CouponMonthYear  CouponID  \
# 51160510  VISACAUSAS2019     7460600  136197641         07/2019  82117962
# 51160511  VISACAUSAS2019     7460600  136197641         07/2019  83296787
# 51160512  VISACAUSAS2019     7460600  136197641         07/2019  85233763
# 51160513  VISACAUSAS2019     7493907  100311481         01/2019  43957702
# 51160514  VISACAUSAS2019     7493907  100311481         01/2019  43986764
# 51160515  VISACAUSAS2019     7493907  100311481         01/2019  44321421
# 51160516  VISACAUSAS2019     7493907  100311481         01/2019  44889423
# 51160517  VISACAUSAS2019     7493907  100311481         01/2019  45909614
# 51160518  VISACAUSAS2019     7493907  100311481         01/2019  45954700
# 51160519  VISACAUSAS2019     7493907  100311481         01/2019  46022404
# 51160520  VISACAUSAS2019     7493907  100311481         01/2019  47023273
# 51160521  VISACAUSAS2019     7493907  100311481         01/2019  47275199
# ...

# %%
df.count()
# Out:
# PromoCode           51160530
# DocumentID          51160530
# CardID              51160530
# CouponMonthYear     51160530
# CouponID            51160530
# InstitutuionSlug    51160530
# dtype: int64

# %%
df['InstitutuionSlug'].value_counts()
# Out:
# instituto_luisa_mell                11225473
# ampara_animal                        7289258
# projeto_tamar                        4556411
# projeto_velho_amigo                  3356766
# grupo_vida_brasil                    2950031
# ici_instituto_do_cancer_infantil     2530735
# casa_do_zezinho                      2103475
# instituto_gerando_falcoes            1857998
# vaga_lume                            1835475
# instituto_guga_kuerten               1818832
# instituto_muda_brasil                1759038
# projeto_guri                         1729612
# instituto_reacao                     1685028
# fundacao_gol_de_letra                1682888
# instituto_ayrton_senna               1681461
# doutores_da_alegria                  1635473
# instituto_verter                     1436571
# instituto_reciclar                     26005
# Name: InstitutuionSlug, dtype: int64

# %%
df['InstitutuionSlug'].str.upper().value_counts(ascending=True).plot.bar(title = 'COUNT DAS INSTITUIÇÕES')

# %%
df.describe()
# Out:
#          DocumentID        CardID      CouponID
# count  5.116053e+07  5.116053e+07  5.116053e+07
# mean   4.505062e+06  9.692049e+07  6.267541e+07
# std    1.903187e+06  3.500346e+07  1.476877e+07
# min    2.000000e+00  1.388410e+05  3.709514e+07
# 25%    3.269178e+06  7.374379e+07  4.988527e+07
# 50%    3.570747e+06  1.010411e+08  6.267541e+07
# 75%    6.756401e+06  1.283491e+08  7.546554e+07
# max    7.493907e+06  1.364255e+08  8.825567e+07

# %%
df.dtypes
# Out:
# PromoCode           object
# DocumentID           int64
# CardID               int64
# CouponMonthYear     object
# CouponID             int64
# InstitutuionSlug    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51160530 entries, 0 to 51160529
# Data columns (total 6 columns):
# PromoCode           object
# DocumentID          int64
# CardID              int64
# CouponMonthYear     object
# CouponID            int64
# InstitutuionSlug    object
# dtypes: int64(3), object(3)
# memory usage: 2.3+ GB

# %%
df['InstitutuionSlug'].value_counts(ascending=True).plot.bar
